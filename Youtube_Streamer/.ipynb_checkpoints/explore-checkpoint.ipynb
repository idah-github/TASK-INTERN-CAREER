# %%
#import py libs
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
#Read csv file

df = pd.read_csv(r"C:\Users\Administrator\Desktop\M&E\Data Analytics\Intern Career\Youtube Streamer\youtubers_df.csv")
df.head(7)
df.tail(9)
# Out:
#      Rank                  Username           Categories  Suscribers  \
# 991   992                  BeAmazed            Educación  11700000.0
# 992   993         5MinuteCraftsLIKE                  NaN  11700000.0
# 993   994  RedChilliesEntertainment                  NaN  11700000.0
# 994   995             VYRLOriginals                  NaN  11700000.0
# 995   996              hamzymukbang                  NaN  11700000.0
# 996   997                Adaahqueen                  NaN  11700000.0
# 997   998      LittleAngelIndonesia       Música y baile  11700000.0
# 998   999              PenMultiplex                  NaN  11700000.0
# 999  1000             OneindiaHindi  Noticias y Política  11700000.0
#
#             Country     Visits    Likes  Comments  \
# 991  Estados Unidos   477800.0   9900.0     556.0
# 992           India     2700.0     28.0       1.0
# 993           India   848300.0  66700.0     842.0
# 994           India    48800.0    949.0     101.0
# ...

# %%
#return column details,type,count..
df.info()
df['Suscribers'].dtype
df.columns
#list row labels and column names
df.axes
#get no. dimensions
df.ndim
df.shape
df.size
#numpy rep of data
df.values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        1000 non-null   int64
#  1   Username    1000 non-null   object
#  2   Categories  694 non-null    object
#  3   Suscribers  1000 non-null   float64
#  4   Country     1000 non-null   object
#  5   Visits      1000 non-null   float64
#  6   Likes       1000 non-null   float64
#  7   Comments    1000 non-null   float64
#  8   Links       1000 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB
# array([[1, 'tseries', 'Música y baile', ..., 2700.0, 78.0,
#         'http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy4_brA'],
#        [2, 'MrBeast', 'Videojuegos, Humor', ..., 5300000.0, 18500.0,
#         'http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8uQQuVA'],
#        [3, 'CoComelon', 'Educación', ..., 24700.0, 0.0,
# ...

# %%
# df.mean
# df.min
# df.std
#descriptive stats for numeric clmns
df.head(20).describe()
# Out:
#            Rank    Suscribers        Visits         Likes      Comments
# count  20.00000  2.000000e+01  2.000000e+01  2.000000e+01     20.000000
# mean   10.50000  1.082000e+08  7.073255e+06  2.984273e+05   1776.950000
# std     5.91608  4.729534e+07  2.603471e+07  1.178867e+06   4415.000953
# min     1.00000  6.660000e+07  7.300000e+03  1.440000e+02      0.000000
# 25%     5.75000  7.555000e+07  6.460000e+04  6.810000e+02      0.000000
# 50%    10.50000  9.425000e+07  4.735500e+05  9.350000e+03     17.000000
# 75%    15.25000  1.120000e+08  2.450000e+06  2.552500e+04    393.500000
# max    20.00000  2.495000e+08  1.174000e+08  5.300000e+06  18500.000000

# %%
#check for null cells per column
df.isnull().sum()
# Out:
# Rank            0
# Username        0
# Categories    306
# Suscribers      0
# Country         0
# Visits          0
# Likes           0
# Comments        0
# Links           0
# dtype: int64

# %%
#unique values 
df.nunique()
# Out:
# Rank          1000
# Username       994
# Categories      45
# Suscribers     274
# Country         29
# Visits         713
# Likes          648
# Comments       389
# Links          994
# dtype: int64

# %%
df.sort_values(by="Visits",ascending=
               False).head()
# Out:
#      Rank               Username          Categories   Suscribers  \
# 1       2                MrBeast  Videojuegos, Humor  183500000.0
# 136   137               MrBeast2       Vlogs diarios   31300000.0
# 153   154              DaFuqBoom    Animación, Humor   29800000.0
# 488   489      BeastPhilanthropy     Comida y bebida   16900000.0
# 288   289  VillageCookingChannel                 NaN   22500000.0
#
#             Country       Visits      Likes  Comments  \
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# 136  Estados Unidos   83100000.0  5000000.0   11600.0
# 153  Estados Unidos   52700000.0  1700000.0   82800.0
# 488  Estados Unidos   21500000.0   952100.0   24000.0
# 288           India   21500000.0   321500.0    5900.0
#
#                                                  Links
# 1    http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 136  http://youtube.com/channel/UC4-79UOlP48-QNGgCk...
# 153  http://youtube.com/channel/UCsSsgPaZ2GSmO6il8C...
# ...

# %%
# df.groupby('Categories').mean
df.corr
# sort_values(by="Likes",ascending=False)
# df[df['Country'].str.contains('India')]
# Out:
# <bound method DataFrame.corr of      Rank              Username           Categories   Suscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# ...

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
numeric_df.head()
numeric_df.corr()
# Out:
#                 Rank  Suscribers    Visits     Likes  Comments
# Rank        1.000000   -0.636552 -0.102714 -0.090913 -0.049194
# Suscribers -0.636552    1.000000  0.245203  0.211639  0.036350
# Visits     -0.102714    0.245203  1.000000  0.950470  0.324067
# Likes      -0.090913    0.211639  0.950470  1.000000  0.325911
# Comments   -0.049194    0.036350  0.324067  0.325911  1.000000

# %%
sbn.heatmap(numeric_df.corr(), annot= True)
plt.show()

# %%
#return random df sample
df.sample(9)
# Out:
#      Rank          Username              Categories  Suscribers  \
# 360   361              VEVO          Música y baile  20100000.0
# 571   572              Zayn          Música y baile  15600000.0
# 956   957        Family-Box               Películas  12000000.0
# 882   883           redbull                Deportes  12600000.0
# 240   241            sagawa                     NaN  24100000.0
# 851   852         BlossomTV                     NaN  12800000.0
# 568   569            FFUNTV                     NaN  15600000.0
# 496   497  SagarKalraShorts           Vlogs diarios  16800000.0
# 643   644    E_MasterSensei  Películas, Videojuegos  14800000.0
#
#             Country     Visits    Likes  Comments  \
# 360  Estados Unidos     9500.0    519.0       7.0
# 571  Estados Unidos   145200.0  20500.0     935.0
# 956           Rusia   177400.0   6300.0      86.0
# 882  Estados Unidos  1400000.0  52300.0     322.0
# 240  Estados Unidos   408800.0  13300.0      55.0
# ...

# %%
df.groupby(['Likes'], sort=True) [['Comments']].mean

df_fl =df[df['Likes'] > 100000]
